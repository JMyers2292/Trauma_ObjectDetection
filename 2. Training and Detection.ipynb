# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('TF', 'workspace'),
    'SCRIPTS_PATH': os.path.join('TF','scripts'),
    'APIMODEL_PATH': os.path.join('TF','models'),
    'ANNOTATION_PATH': os.path.join('TF', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('TF', 'workspace','images'),
    'MODEL_PATH': os.path.join('TF', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('TF', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('TF', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('TF', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('TF', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('TF', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('TF','protoc')
 }

# %%
for path in paths:
    print(path + ": {}".format(paths.get(path)))
# Out:
# WORKSPACE_PATH: TF\workspace
# SCRIPTS_PATH: TF\scripts
# APIMODEL_PATH: TF\models
# ANNOTATION_PATH: TF\workspace\annotations
# IMAGE_PATH: TF\workspace\images
# MODEL_PATH: TF\workspace\models
# PRETRAINED_MODEL_PATH: TF\workspace\pre-trained-models
# CHECKPOINT_PATH: TF\workspace\models\my_ssd_mobnet
# OUTPUT_PATH: TF\workspace\models\my_ssd_mobnet\export
# TFJS_PATH: TF\workspace\models\my_ssd_mobnet\tfjsexport
# TFLITE_PATH: TF\workspace\models\my_ssd_mobnet\tfliteexport
# PROTOC_PATH: TF\protoc

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('TF', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget
# Out:
# Requirement already satisfied: wget in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (3.2)
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\scripts\python.exe -m pip install --upgrade pip' command.

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd TF/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd TF/models/research/slim && pip install -e .
# Out:
#  95% [......................................................................    ] 1409024 / 1468733
# 100% [..........................................................................] 1468733 / 1468733        1 file(s) moved.

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# 2021-07-05 18:20:24.331242: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudart64_110.dll
# Running tests under Python 3.7.3: C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\Scripts\python.exe
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2021-07-05 18:20:41.417721: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-07-05 18:20:42.407396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-07-05 18:20:42.408693: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudart64_110.dll
# 2021-07-05 18:20:42.706228: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cublas64_11.dll
# 2021-07-05 18:20:42.706314: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cublasLt64_11.dll
# 2021-07-05 18:20:42.776793: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cufft64_10.dll
# 2021-07-05 18:20:42.901977: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library curand64_10.dll
# 2021-07-05 18:20:43.117773: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cusolver64_11.dll
# 2021-07-05 18:20:43.209419: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cusparse64_11.dll
# 2021-07-05 18:20:43.223786: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cudnn64_8.dll
# 2021-07-05 18:20:43.356447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-05 18:20:43.360903: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-05 18:20:43.363756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-07-05 18:20:43.363869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2021-07-05 18:20:45.660527: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-05 18:20:45.660554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-07-05 18:20:45.660564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-07-05 18:20:45.667716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 1319 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1050, pci bus id: 0000:02:00.0, compute capability: 6.1)
# C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\model_builder.py:1088: DeprecationWarning: The 'warn' function is deprecated, use 'warning' instead
#   logging.warn(('Building experimental DeepMAC meta-arch.'
# W0705 18:20:46.023832 11672 model_builder.py:1088] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 5.0s
# I0705 18:20:46.315536 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 5.0s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.57s
# I0705 18:20:46.891555 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.57s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# I0705 18:20:47.136487 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.22s
# I0705 18:20:47.360921 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.22s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# W0705 18:20:47.371587 11672 mobilenet_v2.py:296] `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.34s
# I0705 18:20:49.702975 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 2.34s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0705 18:20:49.704547 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0705 18:20:49.723541 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0705 18:20:49.737503 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0705 18:20:49.750467 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.08s
# I0705 18:20:49.831212 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# I0705 18:20:49.907010 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.19s
# I0705 18:20:50.095505 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.19s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.08s
# I0705 18:20:50.175290 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.08s
# I0705 18:20:50.252090 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.08s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# I0705 18:20:50.275028 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0705 18:20:50.415651 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0705 18:20:50.415651 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 64
# I0705 18:20:50.415651 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 3
# I0705 18:20:50.417646 11672 efficientnet_model.py:147] round_filter input=32 output=32
# I0705 18:20:50.430611 11672 efficientnet_model.py:147] round_filter input=32 output=32
# I0705 18:20:50.430611 11672 efficientnet_model.py:147] round_filter input=16 output=16
# I0705 18:20:50.481515 11672 efficientnet_model.py:147] round_filter input=16 output=16
# I0705 18:20:50.482512 11672 efficientnet_model.py:147] round_filter input=24 output=24
# I0705 18:20:50.600201 11672 efficientnet_model.py:147] round_filter input=24 output=24
# I0705 18:20:50.600201 11672 efficientnet_model.py:147] round_filter input=40 output=40
# I0705 18:20:50.713654 11672 efficientnet_model.py:147] round_filter input=40 output=40
# I0705 18:20:50.713654 11672 efficientnet_model.py:147] round_filter input=80 output=80
# I0705 18:20:50.881644 11672 efficientnet_model.py:147] round_filter input=80 output=80
# I0705 18:20:50.881644 11672 efficientnet_model.py:147] round_filter input=112 output=112
# I0705 18:20:51.053219 11672 efficientnet_model.py:147] round_filter input=112 output=112
# I0705 18:20:51.054221 11672 efficientnet_model.py:147] round_filter input=192 output=192
# I0705 18:20:51.287817 11672 efficientnet_model.py:147] round_filter input=192 output=192
# I0705 18:20:51.287817 11672 efficientnet_model.py:147] round_filter input=320 output=320
# I0705 18:20:51.341631 11672 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0705 18:20:51.365981 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0705 18:20:51.409851 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0705 18:20:51.409851 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 88
# I0705 18:20:51.409851 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 4
# I0705 18:20:51.410847 11672 efficientnet_model.py:147] round_filter input=32 output=32
# I0705 18:20:51.423812 11672 efficientnet_model.py:147] round_filter input=32 output=32
# I0705 18:20:51.423812 11672 efficientnet_model.py:147] round_filter input=16 output=16
# I0705 18:20:51.513573 11672 efficientnet_model.py:147] round_filter input=16 output=16
# I0705 18:20:51.513573 11672 efficientnet_model.py:147] round_filter input=24 output=24
# I0705 18:20:51.689064 11672 efficientnet_model.py:147] round_filter input=24 output=24
# I0705 18:20:51.689064 11672 efficientnet_model.py:147] round_filter input=40 output=40
# I0705 18:20:51.860605 11672 efficientnet_model.py:147] round_filter input=40 output=40
# I0705 18:20:51.860605 11672 efficientnet_model.py:147] round_filter input=80 output=80
# I0705 18:20:52.193745 11672 efficientnet_model.py:147] round_filter input=80 output=80
# I0705 18:20:52.193745 11672 efficientnet_model.py:147] round_filter input=112 output=112
# I0705 18:20:52.423159 11672 efficientnet_model.py:147] round_filter input=112 output=112
# I0705 18:20:52.424156 11672 efficientnet_model.py:147] round_filter input=192 output=192
# I0705 18:20:52.709433 11672 efficientnet_model.py:147] round_filter input=192 output=192
# I0705 18:20:52.709433 11672 efficientnet_model.py:147] round_filter input=320 output=320
# I0705 18:20:52.827118 11672 efficientnet_model.py:147] round_filter input=1280 output=1280
# I0705 18:20:52.846067 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0705 18:20:52.904872 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0705 18:20:52.905869 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 112
# I0705 18:20:52.905869 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 5
# I0705 18:20:52.906867 11672 efficientnet_model.py:147] round_filter input=32 output=32
# I0705 18:20:52.918834 11672 efficientnet_model.py:147] round_filter input=32 output=32
# I0705 18:20:52.918834 11672 efficientnet_model.py:147] round_filter input=16 output=16
# I0705 18:20:53.010589 11672 efficientnet_model.py:147] round_filter input=16 output=16
# I0705 18:20:53.010589 11672 efficientnet_model.py:147] round_filter input=24 output=24
# I0705 18:20:53.188114 11672 efficientnet_model.py:147] round_filter input=24 output=24
# I0705 18:20:53.188114 11672 efficientnet_model.py:147] round_filter input=40 output=48
# I0705 18:20:53.359695 11672 efficientnet_model.py:147] round_filter input=40 output=48
# I0705 18:20:53.359695 11672 efficientnet_model.py:147] round_filter input=80 output=88
# I0705 18:20:53.591035 11672 efficientnet_model.py:147] round_filter input=80 output=88
# I0705 18:20:53.591035 11672 efficientnet_model.py:147] round_filter input=112 output=120
# I0705 18:20:53.823948 11672 efficientnet_model.py:147] round_filter input=112 output=120
# I0705 18:20:53.823948 11672 efficientnet_model.py:147] round_filter input=192 output=208
# I0705 18:20:54.107697 11672 efficientnet_model.py:147] round_filter input=192 output=208
# I0705 18:20:54.107697 11672 efficientnet_model.py:147] round_filter input=320 output=352
# I0705 18:20:54.219830 11672 efficientnet_model.py:147] round_filter input=1280 output=1408
# I0705 18:20:54.241728 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0705 18:20:54.295626 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0705 18:20:54.295626 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 160
# I0705 18:20:54.295626 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 6
# I0705 18:20:54.297621 11672 efficientnet_model.py:147] round_filter input=32 output=40
# I0705 18:20:54.310586 11672 efficientnet_model.py:147] round_filter input=32 output=40
# I0705 18:20:54.310586 11672 efficientnet_model.py:147] round_filter input=16 output=24
# I0705 18:20:54.554933 11672 efficientnet_model.py:147] round_filter input=16 output=24
# I0705 18:20:54.554933 11672 efficientnet_model.py:147] round_filter input=24 output=32
# I0705 18:20:54.718497 11672 efficientnet_model.py:147] round_filter input=24 output=32
# I0705 18:20:54.718497 11672 efficientnet_model.py:147] round_filter input=40 output=48
# I0705 18:20:54.884053 11672 efficientnet_model.py:147] round_filter input=40 output=48
# I0705 18:20:54.885048 11672 efficientnet_model.py:147] round_filter input=80 output=96
# I0705 18:20:55.166297 11672 efficientnet_model.py:147] round_filter input=80 output=96
# I0705 18:20:55.166297 11672 efficientnet_model.py:147] round_filter input=112 output=136
# I0705 18:20:55.449537 11672 efficientnet_model.py:147] round_filter input=112 output=136
# I0705 18:20:55.449537 11672 efficientnet_model.py:147] round_filter input=192 output=232
# I0705 18:20:55.808637 11672 efficientnet_model.py:147] round_filter input=192 output=232
# I0705 18:20:55.808637 11672 efficientnet_model.py:147] round_filter input=320 output=384
# I0705 18:20:55.920296 11672 efficientnet_model.py:147] round_filter input=1280 output=1536
# I0705 18:20:55.942275 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0705 18:20:56.010627 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0705 18:20:56.010627 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 224
# I0705 18:20:56.010627 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I0705 18:20:56.012622 11672 efficientnet_model.py:147] round_filter input=32 output=48
# I0705 18:20:56.024590 11672 efficientnet_model.py:147] round_filter input=32 output=48
# I0705 18:20:56.024590 11672 efficientnet_model.py:147] round_filter input=16 output=24
# I0705 18:20:56.119380 11672 efficientnet_model.py:147] round_filter input=16 output=24
# I0705 18:20:56.119380 11672 efficientnet_model.py:147] round_filter input=24 output=32
# I0705 18:20:56.342782 11672 efficientnet_model.py:147] round_filter input=24 output=32
# I0705 18:20:56.342782 11672 efficientnet_model.py:147] round_filter input=40 output=56
# I0705 18:20:56.562661 11672 efficientnet_model.py:147] round_filter input=40 output=56
# I0705 18:20:56.562661 11672 efficientnet_model.py:147] round_filter input=80 output=112
# I0705 18:20:57.026268 11672 efficientnet_model.py:147] round_filter input=80 output=112
# I0705 18:20:57.026268 11672 efficientnet_model.py:147] round_filter input=112 output=160
# I0705 18:20:57.374714 11672 efficientnet_model.py:147] round_filter input=112 output=160
# I0705 18:20:57.374714 11672 efficientnet_model.py:147] round_filter input=192 output=272
# I0705 18:20:57.824297 11672 efficientnet_model.py:147] round_filter input=192 output=272
# I0705 18:20:57.824297 11672 efficientnet_model.py:147] round_filter input=320 output=448
# I0705 18:20:57.936678 11672 efficientnet_model.py:147] round_filter input=1280 output=1792
# I0705 18:20:57.957896 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0705 18:20:58.024715 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0705 18:20:58.024715 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 288
# I0705 18:20:58.024715 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 7
# I0705 18:20:58.026712 11672 efficientnet_model.py:147] round_filter input=32 output=48
# I0705 18:20:58.037681 11672 efficientnet_model.py:147] round_filter input=32 output=48
# I0705 18:20:58.037681 11672 efficientnet_model.py:147] round_filter input=16 output=24
# I0705 18:20:58.174315 11672 efficientnet_model.py:147] round_filter input=16 output=24
# I0705 18:20:58.174315 11672 efficientnet_model.py:147] round_filter input=24 output=40
# I0705 18:20:58.451820 11672 efficientnet_model.py:147] round_filter input=24 output=40
# I0705 18:20:58.451820 11672 efficientnet_model.py:147] round_filter input=40 output=64
# I0705 18:20:58.729090 11672 efficientnet_model.py:147] round_filter input=40 output=64
# I0705 18:20:58.729090 11672 efficientnet_model.py:147] round_filter input=80 output=128
# I0705 18:20:59.120587 11672 efficientnet_model.py:147] round_filter input=80 output=128
# I0705 18:20:59.121584 11672 efficientnet_model.py:147] round_filter input=112 output=176
# I0705 18:20:59.526601 11672 efficientnet_model.py:147] round_filter input=112 output=176
# I0705 18:20:59.526601 11672 efficientnet_model.py:147] round_filter input=192 output=304
# I0705 18:21:00.221594 11672 efficientnet_model.py:147] round_filter input=192 output=304
# I0705 18:21:00.221594 11672 efficientnet_model.py:147] round_filter input=320 output=512
# I0705 18:21:00.394130 11672 efficientnet_model.py:147] round_filter input=1280 output=2048
# I0705 18:21:00.415075 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0705 18:21:00.492868 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0705 18:21:00.492868 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I0705 18:21:00.492868 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I0705 18:21:00.494863 11672 efficientnet_model.py:147] round_filter input=32 output=56
# I0705 18:21:00.506789 11672 efficientnet_model.py:147] round_filter input=32 output=56
# I0705 18:21:00.506789 11672 efficientnet_model.py:147] round_filter input=16 output=32
# I0705 18:21:00.643464 11672 efficientnet_model.py:147] round_filter input=16 output=32
# I0705 18:21:00.643464 11672 efficientnet_model.py:147] round_filter input=24 output=40
# I0705 18:21:00.978259 11672 efficientnet_model.py:147] round_filter input=24 output=40
# I0705 18:21:00.978259 11672 efficientnet_model.py:147] round_filter input=40 output=72
# I0705 18:21:01.319346 11672 efficientnet_model.py:147] round_filter input=40 output=72
# I0705 18:21:01.319346 11672 efficientnet_model.py:147] round_filter input=80 output=144
# I0705 18:21:01.786100 11672 efficientnet_model.py:147] round_filter input=80 output=144
# I0705 18:21:01.786100 11672 efficientnet_model.py:147] round_filter input=112 output=200
# I0705 18:21:02.256330 11672 efficientnet_model.py:147] round_filter input=112 output=200
# I0705 18:21:02.257328 11672 efficientnet_model.py:147] round_filter input=192 output=344
# I0705 18:21:03.084419 11672 efficientnet_model.py:147] round_filter input=192 output=344
# I0705 18:21:03.084419 11672 efficientnet_model.py:147] round_filter input=320 output=576
# I0705 18:21:03.273943 11672 efficientnet_model.py:147] round_filter input=1280 output=2304
# I0705 18:21:03.305828 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0705 18:21:03.443457 11672 ssd_efficientnet_bifpn_feature_extractor.py:143] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0705 18:21:03.444459 11672 ssd_efficientnet_bifpn_feature_extractor.py:144] EfficientDet BiFPN num filters: 384
# I0705 18:21:03.444459 11672 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet BiFPN num iterations: 8
# I0705 18:21:03.446470 11672 efficientnet_model.py:147] round_filter input=32 output=64
# I0705 18:21:03.461409 11672 efficientnet_model.py:147] round_filter input=32 output=64
# I0705 18:21:03.461409 11672 efficientnet_model.py:147] round_filter input=16 output=32
# I0705 18:21:03.716740 11672 efficientnet_model.py:147] round_filter input=16 output=32
# I0705 18:21:03.716740 11672 efficientnet_model.py:147] round_filter input=24 output=48
# I0705 18:21:04.299686 11672 efficientnet_model.py:147] round_filter input=24 output=48
# I0705 18:21:04.299686 11672 efficientnet_model.py:147] round_filter input=40 output=80
# I0705 18:21:04.767436 11672 efficientnet_model.py:147] round_filter input=40 output=80
# I0705 18:21:04.768433 11672 efficientnet_model.py:147] round_filter input=80 output=160
# I0705 18:21:05.478562 11672 efficientnet_model.py:147] round_filter input=80 output=160
# I0705 18:21:05.478562 11672 efficientnet_model.py:147] round_filter input=112 output=224
# I0705 18:21:06.256614 11672 efficientnet_model.py:147] round_filter input=112 output=224
# I0705 18:21:06.257612 11672 efficientnet_model.py:147] round_filter input=192 output=384
# I0705 18:21:07.432551 11672 efficientnet_model.py:147] round_filter input=192 output=384
# I0705 18:21:07.433550 11672 efficientnet_model.py:147] round_filter input=320 output=640
# I0705 18:21:07.719812 11672 efficientnet_model.py:147] round_filter input=1280 output=2560
# I0705 18:21:07.744232 11672 efficientnet_model.py:458] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 17.59s
# I0705 18:21:07.868938 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 17.59s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0705 18:21:07.874915 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0705 18:21:07.876908 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0705 18:21:07.876908 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0705 18:21:07.878902 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0705 18:21:07.880907 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0705 18:21:07.880907 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0705 18:21:07.882859 11672 test_util.py:2103] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 26.572s
#
# OK (skipped=1)

# %%
# !pip install tensorflow --upgrade

# %%
# !pip uninstall protobuf matplotlib -y
# !pip install protobuf matplotlib==3.2

# %%
# !pip install pyyaml

# %%
import object_detection

# %%
# !pip list
# Out:
# Package                 Version             Location
# ----------------------- ------------------- ------------------------------------------------------------------------------------
# absl-py                 0.13.0
# apache-beam             2.31.0rc1
# astunparse              1.6.3
# avro-python3            1.10.2
# backcall                0.2.0
# cached-property         1.5.2
# cachetools              4.2.2
# certifi                 2021.5.30
# chardet                 4.0.0
# colorama                0.4.4
# contextlib2             0.6.0.post1
# cycler                  0.10.0
# cython                  3.0a7
# decorator               5.0.9
# flatbuffers             1.12
# gast                    0.4.0
# google-auth             1.32.0
# google-auth-oauthlib    0.4.4
# google-pasta            0.2.0
# grpcio                  1.34.1
# h5py                    3.1.0
# idna                    2.10
# importlib-metadata      4.5.0
# ipykernel               5.5.5
# ipython                 7.24.1
# ipython-genutils        0.2.0
# jedi                    0.18.0
# jupyter-client          6.1.12
# jupyter-core            4.7.1
# keras-nightly           2.5.0.dev2021032900
# Keras-Preprocessing     1.1.2
# kiwisolver              1.3.1
# lvis                    0.5.3
# lxml                    4.6.3
# Markdown                3.3.4
# matplotlib              3.2.0
# matplotlib-inline       0.1.2
# numpy                   1.19.5
# oauthlib                3.1.1
# object-detection        0.1
# opencv-python           4.5.2.54
# opt-einsum              3.3.0
# pandas                  1.3.0rc1
# parso                   0.8.2
# pickleshare             0.7.5
# pillow                  8.2.0
# pip                     21.1.2
# prompt-toolkit          3.0.19
# protobuf                3.17.3
# pyasn1                  0.4.8
# pyasn1-modules          0.2.8
# pycocotools             2.0.2
# Pygments                2.9.0
# pyparsing               2.4.7
# PyQt5                   5.15.4
# PyQt5-Qt5               5.15.2
# PyQt5-sip               12.9.0
# python-dateutil         2.8.1
# pywin32                 301
# PyYAML                  5.4.1
# pyzmq                   22.1.0
# requests                2.25.1
# requests-oauthlib       1.3.0
# rsa                     4.7.2
# scipy                   1.7.0
# setuptools              57.0.0
# six                     1.15.0
# slim                    0.1                 c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tf\models\research\slim
# tensorboard             2.5.0
# tensorboard-data-server 0.6.1
# tensorboard-plugin-wit  1.8.0
# tensorflow              2.5.0
# tensorflow-estimator    2.5.0
# termcolor               1.1.0
# tf-models-official      2.5.0
# tf-slim                 1.1.0
# tornado                 6.1
# traitlets               5.0.5
# typing-extensions       3.7.4.3
# urllib3                 1.26.5
# wcwidth                 0.2.5
# Werkzeug                2.0.1
# wget                    3.2
# wheel                   0.36.2
# wrapt                   1.12.1
# zipp                    3.4.1

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
#  11% [........                                                                ]  2433024 / 20515344
#  20% [..............                                                          ]  4194304 / 20515344
#  31% [......................                                                  ]  6373376 / 20515344
#  38% [...........................                                             ]  7839744 / 20515344
#  46% [.................................                                       ]  9461760 / 20515344
#  55% [.......................................                                 ] 11337728 / 20515344
#  65% [..............................................                          ] 13377536 / 20515344
#  74% [.....................................................                   ] 15253504 / 20515344
#  82% [...........................................................             ] 16875520 / 20515344
#  90% [................................................................        ] 18489344 / 20515344
#  96% [.....................................................................   ] 19718144 / 20515344
# 100% [........................................................................] 20515344 / 20515344
#         1 file(s) moved.
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# x ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'ThumbsUp', 'id':1}, {'name':'ThumbsDown', 'id':2}, {'name':'FU', 'id':3}, {'name':'Shaka', 'id':4}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# OPTIONAL IF RUNNING ON COLAB
ARCHIVE_FILES = os.path.join(paths['IMAGE_PATH'], 'archive.tar.gz')
if os.path.exists(ARCHIVE_FILES):
  # !tar -zxvf {ARCHIVE_FILES}

# %%
# !pip install pytz
# Out:
# Collecting pytz
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz
# Successfully installed pytz-2021.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# apache-beam 2.31.0rc1 requires crcmod<2.0,>=1.7, which is not installed.
# apache-beam 2.31.0rc1 requires dill<0.3.2,>=0.3.1.1, which is not installed.
# apache-beam 2.31.0rc1 requires fastavro<2,>=0.21.4, which is not installed.
# apache-beam 2.31.0rc1 requires future<1.0.0,>=0.18.2, which is not installed.
# apache-beam 2.31.0rc1 requires hdfs<3.0.0,>=2.1.0, which is not installed.
# apache-beam 2.31.0rc1 requires httplib2<0.20.0,>=0.8, which is not installed.
# apache-beam 2.31.0rc1 requires oauth2client<5,>=2.0.1, which is not installed.
# apache-beam 2.31.0rc1 requires pyarrow<5.0.0,>=0.15.1, which is not installed.
# apache-beam 2.31.0rc1 requires pydot<2,>=1.2.0, which is not installed.
# apache-beam 2.31.0rc1 requires pymongo<4.0.0,>=3.8.0, which is not installed.
# apache-beam 2.31.0rc1 requires avro-python3!=1.9.2,<1.10.0,>=1.8.1, but you have avro-python3 1.10.2 which is incompatible.

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'TF\scripts'...

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: TF\workspace\annotations\train.record
# Successfully created the TFRecord file: TF\workspace\annotations\test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
# Out:
#         1 file(s) copied.

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
# !pip install gin-config==0.1.1
# !pip install tensorflow-addons
# !pip install tensorflow-gpu==2.5.0

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=2000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python TF\models\research\object_detection\model_main_tf2.py --model_dir=TF\workspace\models\my_ssd_mobnet --pipeline_config_path=TF\workspace\models\my_ssd_mobnet\pipeline.config --num_train_steps=2000

# %%
# !{command}
# Out:
# 2021-06-25 11:08:52.890109: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 11:08:52.890147: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Traceback (most recent call last):
#   File "TF\models\research\object_detection\model_main_tf2.py", line 32, in <module>
#     from object_detection import model_lib_v2
#   File "C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\model_lib_v2.py", line 31, in <module>
#     from object_detection import model_lib
#   File "C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\model_lib.py", line 34, in <module>
#     from object_detection.builders import optimizer_builder
#   File "C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\object_detection-0.1-py3.7.egg\object_detection\builders\optimizer_builder.py", line 25, in <module>
#     from official.modeling.optimization import ema_optimizer
#   File "C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\tf_models_official-2.5.0-py3.7.egg\official\modeling\optimization\__init__.py", line 22, in <module>
#     from official.modeling.optimization.optimizer_factory import OptimizerFactory
#   File "C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\tf_models_official-2.5.0-py3.7.egg\official\modeling\optimization\optimizer_factory.py", line 19, in <module>
#     import gin
# ModuleNotFoundError: No module named 'gin'

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python TF\models\research\object_detection\model_main_tf2.py --model_dir=TF\workspace\models\my_ssd_mobnet --pipeline_config_path=TF\workspace\models\my_ssd_mobnet\pipeline.config --checkpoint_dir=TF\workspace\models\my_ssd_mobnet

# %%
# !{command}

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'thumbsup.58851088-d4a9-11eb-8ca6-fdd87725c632.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=5,
            min_score_thresh=.8,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # 10. Real Time Detections from your Webcam

# %%
# !pip uninstall opencv-python-headless -y

# %%
cap = cv2.VideoCapture(0)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

while cap.isOpened(): 
    ret, frame = cap.read()
    image_np = np.array(frame)
    
    input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
    detections = detect_fn(input_tensor)
    
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                  for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    label_id_offset = 1
    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
                image_np_with_detections,
                detections['detection_boxes'],
                detections['detection_classes']+label_id_offset,
                detections['detection_scores'],
                category_index,
                use_normalized_coordinates=True,
                max_boxes_to_draw=5,
                min_score_thresh=.8,
                agnostic_mode=False)

    cv2.imshow('object detection',  cv2.resize(image_np_with_detections, (800, 600)))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python TF\models\research\object_detection\exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=TF\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=TF\workspace\models\my_ssd_mobnet --output_directory=TF\workspace\models\my_ssd_mobnet\export

# %%
# !{command}
# Out:
# 2021-06-25 11:52:45.289428: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 11:52:45.289464: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-06-25 11:52:49.757608: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-06-25 11:52:50.508267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-06-25 11:52:50.509702: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 11:52:50.510971: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-06-25 11:52:50.512215: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-06-25 11:52:50.515693: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cufft64_10.dll
# 2021-06-25 11:52:50.517381: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library curand64_10.dll
# 2021-06-25 11:52:50.518705: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-06-25 11:52:50.519954: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-06-25 11:52:50.521192: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-06-25 11:52:50.521209: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-06-25 11:52:50.521555: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-06-25 11:52:50.522585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 11:52:50.522599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# WARNING:tensorflow:From C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0625 11:52:50.696684 16276 deprecation.py:601] From C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\tensorflow\python\autograph\impl\api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000153327C8A58>, because it is not built.
# W0625 11:53:06.256288 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x00000153327C8A58>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000015332921F98>, because it is not built.
# W0625 11:53:06.346930 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000015332921F98>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6A59B0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6A59B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6A5278>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6A5278>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000001533C6A5588>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000001533C6A5588>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6A52B0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6A52B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C7086A0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C7086A0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000001533C708668>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000001533C708668>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C7081D0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C7081D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C708AC8>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C708AC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000001533C708B00>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000001533C708B00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6E3748>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6E3748>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6E32E8>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6E32E8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000153329374E0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000153329374E0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6F2208>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6F2208>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6F2668>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6F2668>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6F2470>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6F2470>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6F2BE0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6F2BE0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C717048>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C717048>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C7170F0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C7170F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C717B38>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C717B38>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000015332937518>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000015332937518>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C7799E8>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C7799E8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C779978>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C779978>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C775278>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C775278>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C7754A8>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C7754A8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C775EF0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C775EF0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C775E48>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C775E48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C7751D0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C7751D0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C71B550>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C71B550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6DF390>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6DF390>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6DF518>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6DF518>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6DF7F0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6DF7F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6DFEB8>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6DFEB8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6DFE10>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533C6DFE10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6DFDA0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533C6DFDA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015338C4AC88>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015338C4AC88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000015332937550>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000015332937550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533A193CC0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000001533A193CC0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533A193DA0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533A193DA0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015338D9A5F8>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015338D9A5F8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533A2465C0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000001533A2465C0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015338E5B6D8>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015338E5B6D8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000015338E5BF98>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000015338E5BF98>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015339F74CC0>, because it is not built.
# W0625 11:53:06.362510 16276 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000015339F74CC0>, because it is not built.
# 2021-06-25 11:53:14.977745: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# W0625 11:53:29.605890 16276 save.py:243] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# W0625 11:53:34.362233 16276 save.py:1240] FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: TF\workspace\models\my_ssd_mobnet\export\saved_model\assets
# I0625 11:53:34.726529 16276 builder_impl.py:775] Assets written to: TF\workspace\models\my_ssd_mobnet\export\saved_model\assets
# INFO:tensorflow:Writing pipeline config file to TF\workspace\models\my_ssd_mobnet\export\pipeline.config
# I0625 11:53:35.767763 16276 config_util.py:254] Writing pipeline config file to TF\workspace\models\my_ssd_mobnet\export\pipeline.config

# %% [markdown]
# # 11. Conversion to TFJS

# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-3.7.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: six<2,>=1.12.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (1.15.0)
# Collecting tensorflow-hub<0.13,>=0.7.0
#   Using cached tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: tensorflow<3,>=2.1.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflowjs) (2.5.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0.dev2021032900)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.4.0)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-models-official 2.5.0 requires google-api-python-client>=1.6.7, which is not installed.
# tf-models-official 2.5.0 requires google-cloud-bigquery>=0.31.0, which is not installed.
# tf-models-official 2.5.0 requires kaggle>=1.3.9, which is not installed.
# tf-models-official 2.5.0 requires oauth2client, which is not installed.
# tf-models-official 2.5.0 requires opencv-python-headless, which is not installed.
# tf-models-official 2.5.0 requires psutil>=5.4.3, which is not installed.
# tf-models-official 2.5.0 requires py-cpuinfo>=3.3.0, which is not installed.
# tf-models-official 2.5.0 requires sacrebleu, which is not installed.
# tf-models-official 2.5.0 requires sentencepiece, which is not installed.
# tf-models-official 2.5.0 requires seqeval, which is not installed.
# tf-models-official 2.5.0 requires tensorflow-datasets, which is not installed.
# tf-models-official 2.5.0 requires tensorflow-model-optimization>=0.4.1, which is not installed.
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.3.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.13.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.19.5)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.17.3)
# Requirement already satisfied: wheel~=0.35 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (0.36.2)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.34.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (1.12)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorflow<3,>=2.1.0->tensorflowjs) (3.7.4.3)
# Requirement already satisfied: cached-property in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from h5py~=3.1.0->tensorflow<3,>=2.1.0->tensorflowjs) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (57.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.25.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.32.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.3.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (4.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\jeremy\desktop\tensorflow\model training\tfodcourse\tfod\lib\site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow<3,>=2.1.0->tensorflowjs) (3.4.1)
# Installing collected packages: tensorflow-hub, tensorflowjs
# Successfully installed tensorflow-hub-0.12.0 tensorflowjs-3.7.0

# %%
command = "tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default {} {}".format(os.path.join(paths['OUTPUT_PATH'], 'saved_model'), paths['TFJS_PATH'])

# %%
print(command)
# Out:
# tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model --signature_name=serving_default TF\workspace\models\my_ssd_mobnet\export\saved_model TF\workspace\models\my_ssd_mobnet\tfjsexport

# %%
# !{command}
# Out:
# Writing weight file TF\workspace\models\my_ssd_mobnet\tfjsexport\model.json...
# 2021-06-25 11:58:41.560245: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 11:58:41.560287: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-06-25 11:58:49.022763: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-06-25 11:58:49.798428: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-06-25 11:58:49.801398: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 11:58:49.804258: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-06-25 11:58:49.807026: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-06-25 11:58:49.814100: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cufft64_10.dll
# 2021-06-25 11:58:49.817477: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library curand64_10.dll
# 2021-06-25 11:58:49.820417: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-06-25 11:58:49.823180: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-06-25 11:58:49.826196: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-06-25 11:58:49.826277: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-06-25 11:58:49.826778: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-06-25 11:58:49.829025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 11:58:49.829082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-06-25 11:58:59.880616: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2021-06-25 11:58:59.885596: I tensorflow/core/grappler/clusters/single_machine.cc:357] Starting new session
# 2021-06-25 11:58:59.887910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-06-25 11:58:59.887932: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-06-25 11:59:00.031762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 11:59:00.031783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-06-25 11:59:00.031789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2021-06-25 11:59:00.439122: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   function_optimizer: Graph size after: 3841 nodes (3432), 8222 edges (7806), time = 235.824ms.
#   function_optimizer: function_optimizer did nothing. time = 6.258ms.
#
# 2021-06-25 11:59:04.314759: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   debug_stripper: Graph size after: 3554 nodes (0), 7993 edges (0), time = 16.797ms.
#   model_pruner: Graph size after: 3111 nodes (-443), 7550 edges (-443), time = 66.945ms.
#   constant_folding: Graph size after: 1530 nodes (-1581), 5720 edges (-1830), time = 226.478ms.
#   arithmetic_optimizer: Graph size after: 1546 nodes (16), 5744 edges (24), time = 50.307ms.
#   dependency_optimizer: Graph size after: 1456 nodes (-90), 1648 edges (-4096), time = 33.273ms.
#   model_pruner: Graph size after: 1456 nodes (0), 1648 edges (0), time = 14.071ms.
#   constant_folding: Graph size after: 1456 nodes (0), 1648 edges (0), time = 40.804ms.
#   arithmetic_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 31.024ms.
#   dependency_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 19.936ms.
#   debug_stripper: debug_stripper did nothing. time = 2.277ms.
#   model_pruner: Graph size after: 1456 nodes (0), 1648 edges (0), time = 11.904ms.
#   constant_folding: Graph size after: 1456 nodes (0), 1648 edges (0), time = 40.602ms.
#   arithmetic_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 32.997ms.
#   dependency_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 19.408ms.
#   model_pruner: Graph size after: 1456 nodes (0), 1648 edges (0), time = 13.815ms.
#   constant_folding: Graph size after: 1456 nodes (0), 1648 edges (0), time = 40.067ms.
#   arithmetic_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 31.958ms.
#   dependency_optimizer: Graph size after: 1456 nodes (0), 1648 edges (0), time = 19.437ms.
#
# 2021-06-25 11:59:11.778121: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:1144] Optimization results for grappler item: graph_to_optimize
#   remapper: Graph size after: 1420 nodes (-112), 1308 edges (-112), time = 11.72ms.
#   constant_folding: Graph size after: 1116 nodes (-304), 1308 edges (0), time = 67.657ms.
#   arithmetic_optimizer: Graph size after: 1116 nodes (0), 1308 edges (0), time = 24.86ms.
#   dependency_optimizer: Graph size after: 1116 nodes (0), 1308 edges (0), time = 15.055ms.
#   remapper: Graph size after: 1116 nodes (0), 1308 edges (0), time = 7.694ms.
#   constant_folding: Graph size after: 1116 nodes (0), 1308 edges (0), time = 31.598ms.
#   arithmetic_optimizer: Graph size after: 1116 nodes (0), 1308 edges (0), time = 27.036ms.
#   dependency_optimizer: Graph size after: 1116 nodes (0), 1308 edges (0), time = 14.938ms.

# %%
# Test Code: https://github.com/nicknochnack/RealTimeSignLanguageDetectionwithTFJS

# %% [markdown]
# # 12. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python TF\models\research\object_detection\export_tflite_graph_tf2.py  --pipeline_config_path=TF\workspace\models\my_ssd_mobnet\pipeline.config --trained_checkpoint_dir=TF\workspace\models\my_ssd_mobnet --output_directory=TF\workspace\models\my_ssd_mobnet\tfliteexport

# %%
# !{command}
# Out:
# 2021-06-25 11:59:39.857907: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 11:59:39.857943: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-06-25 11:59:44.689518: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-06-25 11:59:45.497916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-06-25 11:59:45.499383: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 11:59:45.500651: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-06-25 11:59:45.501901: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-06-25 11:59:45.505404: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cufft64_10.dll
# 2021-06-25 11:59:45.507286: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library curand64_10.dll
# 2021-06-25 11:59:45.508863: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-06-25 11:59:45.510185: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-06-25 11:59:45.511448: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-06-25 11:59:45.511470: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-06-25 11:59:45.511865: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-06-25 11:59:45.513142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 11:59:45.513167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-06-25 11:59:53.049089: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 11:59:53.049109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-06-25 11:59:54.794337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 11:59:54.794359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000002675E7429B0>, because it is not built.
# W0625 11:59:55.514894 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x000002675E7429B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000002675E7FBFD0>, because it is not built.
# W0625 11:59:55.635929 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x000002675E7FBFD0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662A9860>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662A9860>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A9DD8>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A9DD8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x00000267662A99B0>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x00000267662A99B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676497E2E8>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676497E2E8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766270048>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766270048>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x00000267662703C8>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x00000267662703C8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766270A90>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766270A90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766270C88>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766270C88>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000026766270B00>, because it is not built.
# W0625 11:59:55.636967 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.convolutional.SeparableConv2D object at 0x0000026766270B00>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662BE710>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662BE710>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662BEAC8>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662BEAC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002675E831518>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002675E831518>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766265D68>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766265D68>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766265780>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766265780>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A1198>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A1198>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766264518>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766264518>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A17F0>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A17F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676497C748>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676497C748>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A1A90>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662A1A90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002675E831550>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002675E831550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662CCF60>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662CCF60>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662CC780>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662CC780>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662B6470>, because it is not built.
# W0625 11:59:55.637925 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662B6470>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662B6438>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662B6438>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662B6C18>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662B6C18>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662B6AC8>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662B6AC8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662B6DD8>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662B6DD8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662E5C50>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662E5C50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662C5940>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662C5940>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662C5860>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662C5860>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026765E697F0>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026765E697F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026765E692E8>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026765E692E8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026764B0A898>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026764B0A898>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662112B0>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x00000267662112B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662110F0>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662110F0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002675E831588>, because it is not built.
# W0625 11:59:55.638921 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002675E831588>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002676627D278>, because it is not built.
# W0625 11:59:55.639919 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002676627D278>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676627D898>, because it is not built.
# W0625 11:59:55.639919 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676627D898>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002676627D2B0>, because it is not built.
# W0625 11:59:55.639919 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x000002676627D2B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676627D550>, because it is not built.
# W0625 11:59:55.639919 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x000002676627D550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662949B0>, because it is not built.
# W0625 11:59:55.639919 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x00000267662949B0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766294978>, because it is not built.
# W0625 11:59:55.639919 20340 save_impl.py:77] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x0000026766294978>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766294DD8>, because it is not built.
# W0625 11:59:55.639919 20340 save_impl.py:77] Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Lambda object at 0x0000026766294DD8>, because it is not built.
# 2021-06-25 12:00:04.629848: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2021-06-25 12:00:06.180281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 12:00:06.180302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# W0625 12:00:19.222661 20340 save.py:243] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 260). These functions will not be directly callable after loading.
# C:\Users\Jeremy\Desktop\TensorFlow\Model Training\TFODCourse\tfod\lib\site-packages\tensorflow\python\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# WARNING:tensorflow:FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# W0625 12:00:23.809020 20340 save.py:1240] FOR KERAS USERS: The object that you are saving contains one or more Keras models or layers. If you are loading the SavedModel with `tf.keras.models.load_model`, continue reading (otherwise, you may ignore the following instructions). Please change your code to save with `tf.keras.models.save_model` or `model.save`, and confirm that the file "keras.metadata" exists in the export directory. In the future, Keras will only load the SavedModels that have this file. In other words, `tf.saved_model.save` will no longer write SavedModels that can be recovered as Keras models (this will apply in TF 2.5).
#
# FOR DEVS: If you are overwriting _tracking_metadata in your class, this property has been used to save metadata in the SavedModel. The metadta field will be deprecated soon, so please move the metadata to a different file.
# INFO:tensorflow:Assets written to: TF\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\assets
# I0625 12:00:24.233826 20340 builder_impl.py:775] Assets written to: TF\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=TF\workspace\models\my_ssd_mobnet\tfliteexport\saved_model --output_file=TF\workspace\models\my_ssd_mobnet\tfliteexport\saved_model\detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2021-06-25 12:00:28.664548: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 12:00:28.664595: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-06-25 12:00:32.920057: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library nvcuda.dll
# 2021-06-25 12:00:33.727337: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-06-25 12:00:33.731136: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-06-25 12:00:33.734695: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublas64_11.dll'; dlerror: cublas64_11.dll not found
# 2021-06-25 12:00:33.738016: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cublasLt64_11.dll'; dlerror: cublasLt64_11.dll not found
# 2021-06-25 12:00:33.745889: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library cufft64_10.dll
# 2021-06-25 12:00:33.749347: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library curand64_10.dll
# 2021-06-25 12:00:33.752054: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusolver64_11.dll'; dlerror: cusolver64_11.dll not found
# 2021-06-25 12:00:33.754063: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cusparse64_11.dll'; dlerror: cusparse64_11.dll not found
# 2021-06-25 12:00:33.755688: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudnn64_8.dll'; dlerror: cudnn64_8.dll not found
# 2021-06-25 12:00:33.755715: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-06-25 12:00:33.756031: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-06-25 12:00:33.757616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 12:00:33.757651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-06-25 12:00:45.650619: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:345] Ignored output_format.
# 2021-06-25 12:00:45.650651: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:348] Ignored drop_control_dependency.
# 2021-06-25 12:00:45.650659: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:354] Ignored change_concat_input_ranges.
# 2021-06-25 12:00:45.655362: I tensorflow/cc/saved_model/reader.cc:38] Reading SavedModel from: TF\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-06-25 12:00:45.791433: I tensorflow/cc/saved_model/reader.cc:90] Reading meta graph with tags { serve }
# 2021-06-25 12:00:45.791476: I tensorflow/cc/saved_model/reader.cc:132] Reading SavedModel debug info (if present) from: TF\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-06-25 12:00:45.791634: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 12:00:45.791644: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]
# 2021-06-25 12:00:46.372677: I tensorflow/cc/saved_model/loader.cc:206] Restoring SavedModel bundle.
# 2021-06-25 12:00:47.370469: I tensorflow/cc/saved_model/loader.cc:190] Running initialization op on SavedModel bundle at path: TF\workspace\models\my_ssd_mobnet\tfliteexport\saved_model
# 2021-06-25 12:00:47.823371: I tensorflow/cc/saved_model/loader.cc:277] SavedModel load for tags { serve }; Status: success: OK. Took 2168005 microseconds.
# 2021-06-25 12:00:49.147548: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:210] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2021-06-25 12:00:50.760509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1050 computeCapability: 6.1
# coreClock: 1.493GHz coreCount: 5 deviceMemorySize: 2.00GiB deviceMemoryBandwidth: 104.43GiB/s
# 2021-06-25 12:00:50.760590: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1766] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-06-25 12:00:50.924933: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-06-25 12:00:50.924955: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2021-06-25 12:00:50.924962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N

# %% [markdown]
# # 13. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}

# %%
from google.colab import drive
drive.mount('/content/drive')
